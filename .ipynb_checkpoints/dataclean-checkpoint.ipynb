# %%
import pandas as pd
import re
import seaborn
import numpy as np

# %%
df = pd.read_csv('testNine.csv')

# %%
df.shape
# Out:
# (281, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             281 non-null    int64
#  1   index                  281 non-null    int64
#  2   id                     281 non-null    int64
#  3   offset                 240 non-null    float64
#  4   xmin                   281 non-null    int64
#  5   ymin                   281 non-null    int64
#  6   xmax                   281 non-null    int64
#  7   ymax                   281 non-null    int64
#  8   label                  281 non-null    object
#  9   car_direction          240 non-null    object
#  10  car_curv               240 non-null    float64
#  11  lane_Two_firstPoint    243 non-null    object
#  12  lane_Two_midPoint      243 non-null    object
#  13  lane_Two_lastPoint     243 non-null    object
#  14  lane_Three_firstPoint  240 non-null    object
#  15  lane_Three_midPoint    240 non-null    object
#  16  lane_Three_lastPoint   240 non-null    object
# dtypes: float64(2), int64(7), object(8)
# memory usage: 37.4+ KB

# %%
df
# Out:
#      Unnamed: 0  index   id    offset  xmin  ymin  xmax  ymax  label  \
# 0             0      2    2  0.178726   555     5   684  1277    car
# 1             1      3    2  0.178726   366   615   413   671    car
# 2             2      4    3  0.192303   365   615   412   671    car
# 3             3      5    3  0.192303   554     2   682  1276    car
# 4             4      6    4  0.170745   363   614   409   670    car
# ..          ...    ...  ...       ...   ...   ...   ...   ...    ...
# 276         276    335  182       NaN    67   493   524  1278    car
# 277         277    336  183       NaN    83   521   523  1278    car
# 278         278    337  184       NaN    93   531   524  1278    car
# 279         279    338  185       NaN   103   541   523  1279  truck
# 280         280    339  186       NaN   116   562   522  1279    car
#
#     car_direction     car_curv lane_Two_firstPoint lane_Two_midPoint  \
# 0               F  3410.357597            596, 402          415, 561
# 1               F  3410.357597            596, 402          415, 561
# 2               F  1279.078799            595, 402          414, 561
# 3               F  1279.078799            595, 402          414, 561
# 4               F  2946.291478            590, 402          412, 561
# ..            ...          ...                 ...               ...
# 276           NaN          NaN                 NaN               NaN
# 277           NaN          NaN                 NaN               NaN
# 278           NaN          NaN                 NaN               NaN
# 279           NaN          NaN                 NaN               NaN
# 280           NaN          NaN                 NaN               NaN
#
#     lane_Two_lastPoint lane_Three_firstPoint lane_Three_midPoint  \
# 0             228, 720              684, 408            845, 478
# 1             228, 720              684, 408            845, 478
# 2             228, 720              697, 408            845, 478
# 3             228, 720              697, 408            845, 478
# 4             227, 720              678, 402            839, 472
# ..                 ...                   ...                 ...
# 276                NaN                   NaN                 NaN
# 277                NaN                   NaN                 NaN
# 278                NaN                   NaN                 NaN
# 279                NaN                   NaN                 NaN
# 280                NaN                   NaN                 NaN
#
#     lane_Three_lastPoint
# 0               993, 543
# 1               993, 543
# 2               993, 543
# 3               993, 543
# 4               993, 543
# ..                   ...
# 276                  NaN
# 277                  NaN
# 278                  NaN
# 279                  NaN
# 280                  NaN
#
# [281 rows x 17 columns]

# %%
# for i in range(1,50):
#     df[f'point{i}'] =

# %%
# for i in df['lane2_points']:
#     pointList = []
#     foundList = re.findall(r'\(\d{3},\s\d{3}\)',i)
#     for j in range(len(foundList)):
#         df.insert(j, f'point{j}', foundList[j])
# #         print(foundList[j])
#     print(i)

# %%
# # lane Two
# firstPointList = []
# midPointList = []
# lastPointList = []

# for i in df['lane2_points']:
#     foundlist = re.findall(r'\(\d{3},\s\d{3}\)',i)
#     if foundlist == []:
#         firstPointList.append(None)
#         midPointList.append(None)
#         lastPointList.append(None)
#     else:
#         firstPointList.append(foundlist[0].strip(r'()'))
#         midPointList.append(foundlist[int(len(foundlist)/2)].strip(r"()"))
#         lastPointList.append(foundlist[-1].strip(r"()"))
# #     print(foundpat.group().strip(r'()'))
# df['lane_Two_firstPoint'] = firstPointList
# df['lane_Two_midPoint'] = midPointList
# df['lane_Two_lastPoint'] = lastPointList

# %%
# # lane Three 
# firstPointList = []
# midPointList = []
# lastPointList = []
# for i in df['lane3_points']:
#     foundlist = re.findall(r'\(\d{3},\s\d{3}\)',i)
#     if foundlist == []:
#         firstPointList.append(None)
#         midPointList.append(None)
#         lastPointList.append(None)
#     else:
#         firstPointList.append(foundlist[0].strip(r'()'))
#         midPointList.append(foundlist[int(len(foundlist)/2)].strip(r"()"))
#         lastPointList.append(foundlist[-1].strip(r"()"))
# #     print(foundpat.group().strip(r'()'))
# df['lane_Three_firstPoint'] = firstPointList
# df['lane_Three_midPoint'] = midPointList
# df['lane_Three_lastPoint'] = lastPointList
# df = df.drop(df[(df['car_curv'] > 10000)].index)
# df = df.drop(["lane1_detected",
#              "lane2_detected",
#              "lane3_detected",
#              "lane4_detected",
#              "lane1_points",
#              "lane2_points",
#              "lane3_points",
#              "lane4_points"], axis=1)

# %%
df.lane_Three_firstPoint.loc

# %%
from numpy import ones,vstack
from numpy.linalg import lstsq
points = [(1,5),(3,4)]
x_coords, y_coords = zip(*points)
A = vstack([x_coords,ones(len(x_coords))]).T
m, c = lstsq(A, y_coords)[0]
print("Line Solution is y = {m}x + {c}".format(m=m,c=c))
# Out:
# Line Solution is y = -0.5000000000000002x + 5.5
# C:\Users\Rayan\AppData\Local\Temp\ipykernel_8208\299331317.py:6: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, c = lstsq(A, y_coords)[0]

# %%
# df = df.drop(["lane1_detected",
#              "lane2_detected",
#              "lane3_detected",
#              "lane4_detected",
#              "lane1_points",
#              "lane2_points",
#              "lane3_points",
#              "lane4_points"], axis=1)

# %%
# Q1 = np.percentile(df['car_curv'], 25, interpolation = 'midpoint')

# Q3 = np.percentile(df['car_curv'], 75, interpolation = 'midpoint')

# IQR = Q3 - Q1
               
# print('lower limit of outliers ', Q1 - 1.5*(IQR))
# print('higher limit of outliers', Q3 + 1.5*(IQR))

df = df.drop(df[(df['car_curv'] > 10000)].index)

# %%
seaborn.boxplot(df, x='car_curv')
# Out:
# <Axes: xlabel='car_curv'>

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      Unnamed: 0  index   id    offset  xmin  ymin  xmax  ymax  label  \
# 0             0      2    2  0.178726   555     5   684  1277    car
# 1             1      3    2  0.178726   366   615   413   671    car
# 2             2      4    3  0.192303   365   615   412   671    car
# 3             3      5    3  0.192303   554     2   682  1276    car
# 4             4      6    4  0.170745   363   614   409   670    car
# ..          ...    ...  ...       ...   ...   ...   ...   ...    ...
# 276         276    335  182       NaN    67   493   524  1278    car
# 277         277    336  183       NaN    83   521   523  1278    car
# 278         278    337  184       NaN    93   531   524  1278    car
# 279         279    338  185       NaN   103   541   523  1279  truck
# 280         280    339  186       NaN   116   562   522  1279    car
#
#     car_direction     car_curv lane_Two_firstPoint lane_Two_midPoint  \
# 0               F  3410.357597            596, 402          415, 561
# 1               F  3410.357597            596, 402          415, 561
# 2               F  1279.078799            595, 402          414, 561
# 3               F  1279.078799            595, 402          414, 561
# 4               F  2946.291478            590, 402          412, 561
# ..            ...          ...                 ...               ...
# 276           NaN          NaN                 NaN               NaN
# 277           NaN          NaN                 NaN               NaN
# 278           NaN          NaN                 NaN               NaN
# 279           NaN          NaN                 NaN               NaN
# 280           NaN          NaN                 NaN               NaN
#
#     lane_Two_lastPoint lane_Three_firstPoint lane_Three_midPoint  \
# 0             228, 720              684, 408            845, 478
# 1             228, 720              684, 408            845, 478
# 2             228, 720              697, 408            845, 478
# 3             228, 720              697, 408            845, 478
# 4             227, 720              678, 402            839, 472
# ..                 ...                   ...                 ...
# 276                NaN                   NaN                 NaN
# 277                NaN                   NaN                 NaN
# 278                NaN                   NaN                 NaN
# 279                NaN                   NaN                 NaN
# 280                NaN                   NaN                 NaN
#
#     lane_Three_lastPoint
# 0               993, 543
# 1               993, 543
# 2               993, 543
# 3               993, 543
# 4               993, 543
# ..                   ...
# 276                  NaN
# 277                  NaN
# 278                  NaN
# 279                  NaN
# 280                  NaN
#
# [281 rows x 17 columns]

# %%
df2 = pd.read_csv('all-cases.csv')

# %%
df2['case'] = 0

# %%
df2.to_csv('all-cases.csv')
